# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_pickle('DoE_results_3d_1k.pkl')
points_df = df['points']

n = 101
d = points_df['ratio_d']
pitch = points_df['ratio_pitch']
top_diameter = points_df['ratio_top_diameter']


fig1, ax1 = plt.subplots()
ax1.plot(d,pitch,'o',markersize=2)
ax1.set_xlabel('ratio_pitch') # label of the x axis
ax1.set_ylabel('ratio_top_diameter')
# Out:
# Text(0, 0.5, 'ratio_top_diameter')
